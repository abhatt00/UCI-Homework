# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
unites = "imperial"

query_url = f"{url}appid={api_key}&units&q="
print(query_url)

cityname = []
countryname = []
latitude = []
longitude = []
maxtemp = []
humidity = []
cloudiness = []
date = []
windspeed = []
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=59166562bfec44e3e627176a07991947&units&q=

# %%
count = 1

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    
    try:

        if (count > 500):
            break
        response = requests.get(f"{query_url}{city}").json()
        cityname.append(response["name"])
        countryname.append(response["sys"]["country"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        date.append(response["dt"])
        windspeed.append(response["wind"]["speed"])
        
        print(f"Processing data for City {count} ~ {city}")
        count += 1
        
        # wait for a second to avoid blocking the calls
        time.sleep(1.00)
        
    except:
        print(f"{city} not found, moving on!")
        
    continue
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing data for City 1 ~ vila franca do campo
# Processing data for City 2 ~ mataura
# teul not found, moving on!
# grand river south east not found, moving on!
# Processing data for City 3 ~ buraydah
# Processing data for City 4 ~ east london
# Processing data for City 5 ~ pingliang
# Processing data for City 6 ~ calabozo
# Processing data for City 7 ~ lorengau
# Processing data for City 8 ~ erdenet
# Processing data for City 9 ~ hilo
# Processing data for City 10 ~ kirkenes
# Processing data for City 11 ~ vaini
# Processing data for City 12 ~ hithadhoo
# Processing data for City 13 ~ lavrentiya
# Processing data for City 14 ~ zhanjiang
# Processing data for City 15 ~ jamestown
# taolanaro not found, moving on!
# Processing data for City 16 ~ porto novo
# Processing data for City 17 ~ aljezur
# Processing data for City 18 ~ ushuaia
# Processing data for City 19 ~ leh
# Processing data for City 20 ~ pinerolo
# Processing data for City 21 ~ komsomolskiy
# Processing data for City 22 ~ tuktoyaktuk
# Processing data for City 23 ~ dikson
# Processing data for City 24 ~ pevek
# Processing data for City 25 ~ rikitea
# Processing data for City 26 ~ busselton
# Processing data for City 27 ~ narsaq
# Processing data for City 28 ~ bredasdorp
# Processing data for City 29 ~ cape town
# Processing data for City 30 ~ urzhum
# Processing data for City 31 ~ marshfield
# Processing data for City 32 ~ russell
# Processing data for City 33 ~ castro
# Processing data for City 34 ~ cabo san lucas
# toliary not found, moving on!
# Processing data for City 35 ~ shache
# Processing data for City 36 ~ upernavik
# illoqqortoormiut not found, moving on!
# Processing data for City 37 ~ chuy
# Processing data for City 38 ~ bluff
# Processing data for City 39 ~ kodiak
# Processing data for City 40 ~ sovetskiy
# Processing data for City 41 ~ freeport
# Processing data for City 42 ~ punta arenas
# Processing data for City 43 ~ thompson
# Processing data for City 44 ~ labuhan
# Processing data for City 45 ~ ulladulla
# Processing data for City 46 ~ cidreira
# Processing data for City 47 ~ arraial do cabo
# Processing data for City 48 ~ guerrero negro
# Processing data for City 49 ~ vardo
# Processing data for City 50 ~ victoria
# Processing data for City 51 ~ alugan
# Processing data for City 52 ~ hofn
# Processing data for City 53 ~ clyde river
# Processing data for City 54 ~ piopio
# Processing data for City 55 ~ yuncheng
# Processing data for City 56 ~ hasaki
# tsihombe not found, moving on!
# Processing data for City 57 ~ springbok
# Processing data for City 58 ~ ilulissat
# Processing data for City 59 ~ carballo
# Processing data for City 60 ~ brusturoasa
# Processing data for City 61 ~ karratha
# Processing data for City 62 ~ barrow
# Processing data for City 63 ~ meulaboh
# Processing data for City 64 ~ tessalit
# Processing data for City 65 ~ new norfolk
# Processing data for City 66 ~ griffith
# Processing data for City 67 ~ faanui
# Processing data for City 68 ~ yashan
# Processing data for City 69 ~ srednekolymsk
# Processing data for City 70 ~ masumbwe
# Processing data for City 71 ~ iskateley
# Processing data for City 72 ~ saskylakh
# mys shmidta not found, moving on!
# Processing data for City 73 ~ torbay
# Processing data for City 74 ~ mount gambier
# Processing data for City 75 ~ shreveport
# Processing data for City 76 ~ puerto ayora
# Processing data for City 77 ~ venado tuerto
# Processing data for City 78 ~ yellowknife
# Processing data for City 79 ~ albany
# Processing data for City 80 ~ barentu
# Processing data for City 81 ~ bubaque
# Processing data for City 82 ~ atuona
# Processing data for City 83 ~ hermanus
# Processing data for City 84 ~ sokoni
# Processing data for City 85 ~ bodaybo
# Processing data for City 86 ~ alice springs
# Processing data for City 87 ~ vorukh
# Processing data for City 88 ~ taldan
# Processing data for City 89 ~ kamenka
# Processing data for City 90 ~ barcelos
# Processing data for City 91 ~ saint george
# Processing data for City 92 ~ hobart
# Processing data for City 93 ~ dalby
# Processing data for City 94 ~ bam
# Processing data for City 95 ~ ponta do sol
# Processing data for City 96 ~ bogoslovka
# Processing data for City 97 ~ poso
# Processing data for City 98 ~ joshimath
# vaitupu not found, moving on!
# Processing data for City 99 ~ faya
# asau not found, moving on!
# Processing data for City 100 ~ airai
# Processing data for City 101 ~ port alfred
# satitoa not found, moving on!
# Processing data for City 102 ~ kavieng
# Processing data for City 103 ~ itinga
# Processing data for City 104 ~ pisco
# Processing data for City 105 ~ kapaa
# Processing data for City 106 ~ luganville
# Processing data for City 107 ~ iqaluit
# Processing data for City 108 ~ tiksi
# Processing data for City 109 ~ veraval
# Processing data for City 110 ~ sept-iles
# Processing data for City 111 ~ khatanga
# korla not found, moving on!
# Processing data for City 112 ~ flin flon
# Processing data for City 113 ~ atambua
# Processing data for City 114 ~ hurricane
# Processing data for City 115 ~ jumla
# Processing data for City 116 ~ staraya toropa
# Processing data for City 117 ~ tokur
# Processing data for City 118 ~ sola
# belushya guba not found, moving on!
# Processing data for City 119 ~ kahului
# Processing data for City 120 ~ batemans bay
# Processing data for City 121 ~ qaanaaq
# Processing data for City 122 ~ ereymentau
# Processing data for City 123 ~ saint-georges
# Processing data for City 124 ~ ilhabela
# Processing data for City 125 ~ fairbanks
# Processing data for City 126 ~ eureka
# Processing data for City 127 ~ hatillo
# Processing data for City 128 ~ jacksonville
# Processing data for City 129 ~ georgetown
# Processing data for City 130 ~ mindif
# Processing data for City 131 ~ butaritari
# Processing data for City 132 ~ kuytun
# Processing data for City 133 ~ acapulco
# Processing data for City 134 ~ avarua
# Processing data for City 135 ~ cayenne
# Processing data for City 136 ~ tiznit
# Processing data for City 137 ~ bama
# Processing data for City 138 ~ husavik
# Processing data for City 139 ~ mangrol
# Processing data for City 140 ~ mingaora
# Processing data for City 141 ~ tvoroyri
# Processing data for City 142 ~ tuatapere
# Processing data for City 143 ~ san carlos de bariloche
# Processing data for City 144 ~ darhan
# Processing data for City 145 ~ xai-xai
# Processing data for City 146 ~ hamilton
# Processing data for City 147 ~ la ronge
# Processing data for City 148 ~ cherskiy
# Processing data for City 149 ~ cascais
# Processing data for City 150 ~ mar del plata
# Processing data for City 151 ~ verkhoyansk
# Processing data for City 152 ~ corinto
# Processing data for City 153 ~ aklavik
# Processing data for City 154 ~ mahebourg
# Processing data for City 155 ~ saldanha
# Processing data for City 156 ~ port elizabeth
# Processing data for City 157 ~ sitka
# Processing data for City 158 ~ ribeira grande
# Processing data for City 159 ~ kimberley
# Processing data for City 160 ~ chernyshevskiy
# Processing data for City 161 ~ carnarvon
# Processing data for City 162 ~ nemuro
# Processing data for City 163 ~ mandiana
# Processing data for City 164 ~ baghmara
# gulshat not found, moving on!
# Processing data for City 165 ~ roald
# Processing data for City 166 ~ saint-philippe
# Processing data for City 167 ~ fria
# Processing data for City 168 ~ bandarbeyla
# Processing data for City 169 ~ broome
# Processing data for City 170 ~ lagoa
# Processing data for City 171 ~ mount isa
# Processing data for City 172 ~ bilyayivka
# Processing data for City 173 ~ plouzane
# Processing data for City 174 ~ sur
# samusu not found, moving on!
# Processing data for City 175 ~ pitimbu
# Processing data for City 176 ~ rio gallegos
# linguere not found, moving on!
# Processing data for City 177 ~ constitucion
# Processing data for City 178 ~ bambous virieux
# bacuit not found, moving on!
# Processing data for City 179 ~ dhidhdhoo
# Processing data for City 180 ~ chokurdakh
# Processing data for City 181 ~ tura
# Processing data for City 182 ~ vostok
# grimari not found, moving on!
# Processing data for City 183 ~ iracoubo
# Processing data for City 184 ~ westport
# bengkulu not found, moving on!
# Processing data for City 185 ~ okha
# Processing data for City 186 ~ san cristobal
# Processing data for City 187 ~ namatanai
# Processing data for City 188 ~ aranos
# Processing data for City 189 ~ malanje
# Processing data for City 190 ~ portland
# Processing data for City 191 ~ ugoofaaru
# Processing data for City 192 ~ lata
# attawapiskat not found, moving on!
# Processing data for City 193 ~ trincomalee
# Processing data for City 194 ~ palauig
# ayios kirikos not found, moving on!
# Processing data for City 195 ~ verkhnevilyuysk
# Processing data for City 196 ~ sioux lookout
# Processing data for City 197 ~ baherden
# Processing data for City 198 ~ balkanabat
# Processing data for City 199 ~ provideniya
# Processing data for City 200 ~ saint anthony
# Processing data for City 201 ~ sparks
# Processing data for City 202 ~ skibbereen
# Processing data for City 203 ~ klaksvik
# Processing data for City 204 ~ port hardy
# Processing data for City 205 ~ atherton
# Processing data for City 206 ~ mutsu
# Processing data for City 207 ~ barbosa
# Processing data for City 208 ~ laguna
# Processing data for City 209 ~ ronda
# Processing data for City 210 ~ yulara
# Processing data for City 211 ~ brakel
# Processing data for City 212 ~ balaipungut
# Processing data for City 213 ~ montego bay
# Processing data for City 214 ~ ahipara
# Processing data for City 215 ~ newport
# Processing data for City 216 ~ rusera
# Processing data for City 217 ~ souillac
# Processing data for City 218 ~ vanavara
# barentsburg not found, moving on!
# Processing data for City 219 ~ katsuura
# Processing data for City 220 ~ pandan
# Processing data for City 221 ~ nouadhibou
# Processing data for City 222 ~ sacramento
# Processing data for City 223 ~ port moresby
# Processing data for City 224 ~ barinitas
# Processing data for City 225 ~ taoudenni
# mullaitivu not found, moving on!
# Processing data for City 226 ~ seddon
# Processing data for City 227 ~ saint-augustin
# Processing data for City 228 ~ nalut
# Processing data for City 229 ~ barela
# Processing data for City 230 ~ geraldton
# Processing data for City 231 ~ tiarei
# Processing data for City 232 ~ namibe
# Processing data for City 233 ~ mehamn
# Processing data for City 234 ~ doka
# osku not found, moving on!
# Processing data for City 235 ~ nagato
# Processing data for City 236 ~ tocopilla
# Processing data for City 237 ~ harbin
# Processing data for City 238 ~ manta
# Processing data for City 239 ~ lebu
# Processing data for City 240 ~ byron bay
# Processing data for City 241 ~ esperance
# Processing data for City 242 ~ flinders
# Processing data for City 243 ~ praia da vitoria
# Processing data for City 244 ~ alekseyevka
# Processing data for City 245 ~ aleksandrov gay
# Processing data for City 246 ~ auki
# Processing data for City 247 ~ batagay-alyta
# Processing data for City 248 ~ beloha
# Processing data for City 249 ~ lamar
# Processing data for City 250 ~ dunedin
# Processing data for City 251 ~ mathbaria
# Processing data for City 252 ~ hobyo
# Processing data for City 253 ~ fort nelson
# Processing data for City 254 ~ omaha
# Processing data for City 255 ~ jishu
# Processing data for City 256 ~ salamiyah
# Processing data for City 257 ~ price
# Processing data for City 258 ~ sao filipe
# olafsvik not found, moving on!
# Processing data for City 259 ~ pocone
# Processing data for City 260 ~ kaitangata
# Processing data for City 261 ~ redcliffe
# Processing data for City 262 ~ kingston
# Processing data for City 263 ~ taquari
# marcona not found, moving on!
# Processing data for City 264 ~ liepaja
# Processing data for City 265 ~ chapais
# toulepleu not found, moving on!
# Processing data for City 266 ~ san matias
# Processing data for City 267 ~ bilibino
# Processing data for City 268 ~ tasiilaq
# Processing data for City 269 ~ luanda
# Processing data for City 270 ~ luderitz
# Processing data for City 271 ~ puerto madryn
# Processing data for City 272 ~ rio bravo
# Processing data for City 273 ~ hualmay
# Processing data for City 274 ~ bayaguana
# Processing data for City 275 ~ jasper
# Processing data for City 276 ~ tautira
# Processing data for City 277 ~ jinka
# Processing data for City 278 ~ almaty
# Processing data for City 279 ~ los llanos de aridane
# Processing data for City 280 ~ bocholt
# Processing data for City 281 ~ acajutla
# Processing data for City 282 ~ codrington
# Processing data for City 283 ~ bethel
# Processing data for City 284 ~ sao joao da barra
# Processing data for City 285 ~ henderson
# Processing data for City 286 ~ homer
# Processing data for City 287 ~ miragoane
# Processing data for City 288 ~ nabire
# Processing data for City 289 ~ axim
# Processing data for City 290 ~ zacualpan
# Processing data for City 291 ~ muravlenko
# Processing data for City 292 ~ chengde
# Processing data for City 293 ~ poum
# Processing data for City 294 ~ sabha
# Processing data for City 295 ~ tigil
# Processing data for City 296 ~ shakawe
# Processing data for City 297 ~ pontianak
# Processing data for City 298 ~ khorixas
# Processing data for City 299 ~ gondar
# deh rawud not found, moving on!
# Processing data for City 300 ~ bundaberg
# Processing data for City 301 ~ huarmey
# Processing data for City 302 ~ llangefni
# Processing data for City 303 ~ fortuna
# Processing data for City 304 ~ brownsville
# Processing data for City 305 ~ smidovich
# Processing data for City 306 ~ ixtapa
# Processing data for City 307 ~ moose factory
# louisbourg not found, moving on!
# Processing data for City 308 ~ giddalur
# Processing data for City 309 ~ quesnel
# Processing data for City 310 ~ port lincoln
# aakirkeby not found, moving on!
# Processing data for City 311 ~ okato
# Processing data for City 312 ~ perth
# Processing data for City 313 ~ naze
# Processing data for City 314 ~ san juan del sur
# qui nhon not found, moving on!
# Processing data for City 315 ~ malartic
# Processing data for City 316 ~ mehran
# Processing data for City 317 ~ carora
# Processing data for City 318 ~ el alto
# Processing data for City 319 ~ ishigaki
# Processing data for City 320 ~ kiama
# rungata not found, moving on!
# Processing data for City 321 ~ channel-port aux basques
# Processing data for City 322 ~ turukhansk
# ascension not found, moving on!
# Processing data for City 323 ~ norman wells
# Processing data for City 324 ~ oktyabrskoye
# hendijan not found, moving on!
# Processing data for City 325 ~ panjab
# chatan not found, moving on!
# Processing data for City 326 ~ teya
# Processing data for City 327 ~ albano laziale
# Processing data for City 328 ~ henties bay
# yeletskiy not found, moving on!
# tunduru not found, moving on!
# Processing data for City 329 ~ nicoya
# Processing data for City 330 ~ kijang
# Processing data for City 331 ~ half moon bay
# Processing data for City 332 ~ shirokiy
# bolungarvik not found, moving on!
# wahran not found, moving on!
# Processing data for City 333 ~ palaikastron
# Processing data for City 334 ~ nome
# Processing data for City 335 ~ ostrovnoy
# Processing data for City 336 ~ guhagar
# kismayo not found, moving on!
# Processing data for City 337 ~ vylkove
# Processing data for City 338 ~ matiri
# Processing data for City 339 ~ touros
# Processing data for City 340 ~ port-gentil
# Processing data for City 341 ~ houston
# Processing data for City 342 ~ itigi
# Processing data for City 343 ~ havoysund
# Processing data for City 344 ~ brigantine
# Processing data for City 345 ~ shingu
# Processing data for City 346 ~ bud
# Processing data for City 347 ~ ballina
# Processing data for City 348 ~ bartica
# Processing data for City 349 ~ voyvozh
# Processing data for City 350 ~ kloulklubed
# Processing data for City 351 ~ khovu-aksy
# Processing data for City 352 ~ kinston
# Processing data for City 353 ~ manzanillo
# Processing data for City 354 ~ chipinge
# Processing data for City 355 ~ rincon
# kemijarvi not found, moving on!
# utiroa not found, moving on!
# Processing data for City 356 ~ lulea
# Processing data for City 357 ~ praia
# Processing data for City 358 ~ chicama
# pemangkat not found, moving on!
# Processing data for City 359 ~ vire
# Processing data for City 360 ~ whitehorse
# sedelnikovo not found, moving on!
# Processing data for City 361 ~ boa vista
# amderma not found, moving on!
# Processing data for City 362 ~ maniitsoq
# Processing data for City 363 ~ deputatskiy
# Processing data for City 364 ~ praxedis guerrero
# Processing data for City 365 ~ sakaiminato
# ruatoria not found, moving on!
# Processing data for City 366 ~ nyurba
# Processing data for City 367 ~ roebourne
# Processing data for City 368 ~ hovd
# Processing data for City 369 ~ fez
# Processing data for City 370 ~ sault sainte marie
# Processing data for City 371 ~ nuuk
# Processing data for City 372 ~ tilichiki
# Processing data for City 373 ~ mochudi
# Processing data for City 374 ~ haines junction
# Processing data for City 375 ~ yolombo
# Processing data for City 376 ~ krutinka
# Processing data for City 377 ~ hami
# Processing data for City 378 ~ te anau
# nguiu not found, moving on!
# Processing data for City 379 ~ nizwa
# Processing data for City 380 ~ liverpool
# Processing data for City 381 ~ mayor pablo lagerenza
# porto santo not found, moving on!
# Processing data for City 382 ~ buenos aires
# Processing data for City 383 ~ vanimo
# Processing data for City 384 ~ nanortalik
# Processing data for City 385 ~ marsa matruh
# Processing data for City 386 ~ drayton valley
# Processing data for City 387 ~ harlingen
# Processing data for City 388 ~ mastic beach
# Processing data for City 389 ~ isangel
# Processing data for City 390 ~ saint-pierre
# Processing data for City 391 ~ torrevieja
# Processing data for City 392 ~ pacific grove
# Processing data for City 393 ~ todos santos
# Processing data for City 394 ~ coruripe
# Processing data for City 395 ~ wollongong
# Processing data for City 396 ~ acari
# Processing data for City 397 ~ dingle
# Processing data for City 398 ~ rocha
# nizhneyansk not found, moving on!
# Processing data for City 399 ~ manicore
# Processing data for City 400 ~ minador do negrao
# Processing data for City 401 ~ petropavlovsk-kamchatskiy
# Processing data for City 402 ~ inuvik
# krasnoselkup not found, moving on!
# Processing data for City 403 ~ kudahuvadhoo
# Processing data for City 404 ~ severo-kurilsk
# Processing data for City 405 ~ ozernovskiy
# Processing data for City 406 ~ vladivostok
# Processing data for City 407 ~ itaituba
# Processing data for City 408 ~ wuwei
# Processing data for City 409 ~ santa eulalia
# Processing data for City 410 ~ nantucket
# Processing data for City 411 ~ concepcion del oro
# barawe not found, moving on!
# Processing data for City 412 ~ snezhnogorsk
# Processing data for City 413 ~ champerico
# Processing data for City 414 ~ vao
# Processing data for City 415 ~ longjiang
# Processing data for City 416 ~ tateyama
# Processing data for City 417 ~ alta floresta
# linchuan not found, moving on!
# kuah not found, moving on!
# Processing data for City 418 ~ hope
# Processing data for City 419 ~ camacha
# Processing data for City 420 ~ gimli
# Processing data for City 421 ~ altus
# Processing data for City 422 ~ waingapu
# Processing data for City 423 ~ valvedditturai
# Processing data for City 424 ~ kamaishi
# Processing data for City 425 ~ kendari
# Processing data for City 426 ~ nara
# Processing data for City 427 ~ rio grande
# Processing data for City 428 ~ kedougou
# Processing data for City 429 ~ florianopolis
# Processing data for City 430 ~ moussoro
# Processing data for City 431 ~ urusha
# Processing data for City 432 ~ carlsbad
# Processing data for City 433 ~ harper
# Processing data for City 434 ~ mackay
# Processing data for City 435 ~ yar-sale
# Processing data for City 436 ~ vila velha
# Processing data for City 437 ~ tubuala
# Processing data for City 438 ~ shimoda
# Processing data for City 439 ~ mae sai
# Processing data for City 440 ~ abu kamal
# Processing data for City 441 ~ valparaiso
# Processing data for City 442 ~ kruisfontein
# Processing data for City 443 ~ erenhot
# Processing data for City 444 ~ ancud
# Processing data for City 445 ~ batagay
# Processing data for City 446 ~ derzhavinsk
# Processing data for City 447 ~ atar
# Processing data for City 448 ~ san juan
# Processing data for City 449 ~ semnan
# sentyabrskiy not found, moving on!
# Processing data for City 450 ~ iberia
# Processing data for City 451 ~ konongo
# Processing data for City 452 ~ saint albans
# Processing data for City 453 ~ san andres
# Processing data for City 454 ~ ambovombe
# Processing data for City 455 ~ port said
# Processing data for City 456 ~ vestmannaeyjar
# Processing data for City 457 ~ moosomin
# Processing data for City 458 ~ mitzic
# Processing data for City 459 ~ kieta
# Processing data for City 460 ~ schmalkalden
# Processing data for City 461 ~ ossora
# Processing data for City 462 ~ mildura
# Processing data for City 463 ~ salalah
# Processing data for City 464 ~ srikakulam
# Processing data for City 465 ~ nipawin
# Processing data for City 466 ~ baghdad
# Processing data for City 467 ~ caravelas
# Processing data for City 468 ~ mount darwin
# Processing data for City 469 ~ neya
# Processing data for City 470 ~ linxia
# addis zemen not found, moving on!
# hihifo not found, moving on!
# Processing data for City 471 ~ lohardaga
# Processing data for City 472 ~ tecoanapa
# Processing data for City 473 ~ goderich
# Processing data for City 474 ~ gaoual
# Processing data for City 475 ~ fereydunshahr
# Processing data for City 476 ~ nikolskoye
# Processing data for City 477 ~ comodoro rivadavia
# Processing data for City 478 ~ kindu
# Processing data for City 479 ~ betare oya
# Processing data for City 480 ~ gavle
# Processing data for City 481 ~ ondjiva
# Processing data for City 482 ~ bathsheba
# Processing data for City 483 ~ astana
# Processing data for City 484 ~ durban
# Processing data for City 485 ~ ambilobe
# Processing data for City 486 ~ altay
# Processing data for City 487 ~ jaguaruna
# Processing data for City 488 ~ kasempa
# bairiki not found, moving on!
# Processing data for City 489 ~ tianpeng
# Processing data for City 490 ~ las tunas
# Processing data for City 491 ~ khani
# Processing data for City 492 ~ eyl
# Processing data for City 493 ~ paso de patria
# Processing data for City 494 ~ yumen
# Processing data for City 495 ~ saint-francois
# Processing data for City 496 ~ urucui
# Processing data for City 497 ~ talnakh
# Processing data for City 498 ~ guanare
# Processing data for City 499 ~ dhekiajuli
# Processing data for City 500 ~ tarko-sale

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather = {
    "City": cityname,
    "Cloudiness": cloudiness, 
    "Country": countryname,
    "Date": date, 
    "Humidity": humidity,
    "Latitude": latitude, 
    "Longitude": longitude, 
    "Max Temp": maxtemp,
    "Wind Speed":windspeed
}

weather_df = pd.DataFrame(weather)
weather_df.count()
# Out:
# City          500
# Cloudiness    500
# Country       500
# Date          500
# Humidity      500
# Latitude      500
# Longitude     500
# Max Temp      500
# Wind Speed    500
# dtype: int64

# %%
weather_df.to_csv(output_data_file)
weather_df.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity  Latitude  \
# 0  Vila Franca do Campo          20      PT  1570170485        94     37.72
# 1               Mataura          99      NZ  1570170486        55    -46.19
# 2              Buraydah           0      SA  1570170488        33     26.33
# 3           East London          75      ZA  1570170489        77    -33.02
# 4             Pingliang          99      CN  1570170490        74     35.54
#
#    Longitude  Max Temp  Wind Speed
# 0     -25.43   293.710        5.70
# 1     168.86   288.710        6.26
# 2      43.97   303.150        5.70
# 3      27.91   291.150        2.60
# 4     106.68   284.839        2.90

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
area = (30 * np.random.rand(len(weather_df)))**2
colors = np.random.rand(len(weather_df))

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df["Latitude"], weather_df["Max Temp"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Temperature ({time.strftime('%x')})")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsTemperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df["Latitude"], weather_df["Humidity"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Humidity ({time.strftime('%x')})")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.ylim(0, 100)
plt.grid(True)


plt.tight_layout()
plt.savefig("LatitudeVsHumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df["Latitude"], weather_df["Cloudiness"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Cloudiness ({time.strftime('%x')})")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsCloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10, 8))
plt.scatter(weather_df["Latitude"], weather_df["Wind Speed"], marker="o", s=area, c=colors, alpha=0.5)
plt.title(f"Latitude Vs Wind Speed ({time.strftime('%x')})")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.tight_layout()
plt.savefig("LatitudeVsWindSpeed.png")
plt.show()
